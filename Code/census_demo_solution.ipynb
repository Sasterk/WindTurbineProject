# %% [markdown]
# # U.S. Census Demo

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# %%
# Read in the csv file
wind_turbine_df = pd.read_csv('../Resources/uswtdb_v6_0_20230531.csv')
wind_turbine_df
# Out:
#        case_id    faa_ors           faa_asn  usgs_pr_id  eia_id t_state  \
# 0      3123233  40-097764  2021-WTW-7887-OE         NaN     NaN      OK
# 1      3123609  40-097526  2021-WTW-7898-OE         NaN     NaN      OK
# 2      3119868  40-097497  2021-WTW-7912-OE         NaN     NaN      OK
# 3      3123202  40-097556  2021-WTW-7875-OE         NaN     NaN      OK
# 4      3124077  40-097543  2021-WTW-7885-OE         NaN     NaN      OK
# ...        ...        ...               ...         ...     ...     ...
# 72726  3053232  36-120351  2015-WTE-5788-OE         NaN     NaN      NY
# 72727  3101958  48-171972  2020-WTW-2021-OE         NaN     NaN      TX
# 72728  3040944  48-024978   2011-WTW-352-OE     41364.0     NaN      TX
# 72729  3055917  08-072245  2015-WTW-9994-OE         NaN     NaN      CO
# 72730  3055918  08-072237  2015-WTW-9995-OE         NaN     NaN      CO
#
#              t_county  t_fips                  p_name  p_year  ...     t_rsa  \
# 0        Ellis County   40045           25 Mile Creek  2022.0  ...  17671.46
# 1        Ellis County   40045           25 Mile Creek  2022.0  ...  17671.46
# 2        Ellis County   40045           25 Mile Creek  2022.0  ...  17671.46
# 3        Ellis County   40045           25 Mile Creek  2022.0  ...  17671.46
# 4        Ellis County   40045           25 Mile Creek  2022.0  ...  17671.46
# ...               ...     ...                     ...     ...  ...       ...
# 72726  Wyoming County   36121  unknown Wyoming County  2016.0  ...       NaN
# 72727    Young County   48503    unknown Young County     NaN  ...       NaN
# 72728    Young County   48503  unknown Young County 1  2011.0  ...       NaN
# 72729     Yuma County    8125     unknown Yuma County  2016.0  ...       NaN
# 72730     Yuma County    8125     unknown Yuma County  2016.0  ...       NaN
#
#        t_ttlh retrofit retrofit_year  t_conf_atr  t_conf_loc  t_img_date  \
# 0       180.0        0           NaN           1           3    1/4/2023
# 1       180.0        0           NaN           1           3    1/4/2023
# 2       180.0        0           NaN           1           3    1/4/2023
# 3       180.0        0           NaN           1           3    1/4/2023
# 4       180.0        0           NaN           1           3    1/4/2023
# ...       ...      ...           ...         ...         ...         ...
# 72726     NaN        0           NaN           1           3   5/20/2017
# 72727     NaN        0           NaN           1           1  10/26/2022
# 72728     NaN        0           NaN           1           3   7/16/2018
# 72729     NaN        0           NaN           1           3   5/17/2017
# 72730     NaN        0           NaN           1           3   5/17/2017
#
#           t_img_srce       xlong       ylat
# 0      Digital Globe  -99.775963  36.458096
# 1      Digital Globe  -99.751343  36.446674
# 2      Digital Globe  -99.735718  36.423359
# 3      Digital Globe  -99.782372  36.484463
# 4      Digital Globe  -99.782089  36.473541
# ...              ...         ...        ...
# 72726  Digital Globe  -78.187935  42.740818
# 72727  Digital Globe  -98.907600  33.149414
# 72728  Digital Globe  -98.551094  33.093292
# 72729  Digital Globe -102.717171  40.035072
# 72730  Digital Globe -102.716949  40.037548
#
# [72731 rows x 27 columns]
